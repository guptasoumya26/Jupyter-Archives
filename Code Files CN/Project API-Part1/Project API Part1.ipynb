# %%
import requests
import json
from requests.auth import HTTPBasicAuth

para={"city_id":1}
header={"user-key":"db5cc0c3fa8e6679c4f19aeb201c1c0c"}
a=requests.get('https://developers.zomato.com/api/v2.1/cuisines',params=para,headers=header)
pdata=json.loads(a.text)
print(a.url)
for i in pdata['cuisines']:
    if (i['cuisine']['cuisine_name']=='Mexican'):
        print(i['cuisine']['cuisine_id'])
# Out:
# https://developers.zomato.com/api/v2.1/cuisines?city_id=1
# 73

# %% [markdown]
# Fetch the entityid and entitytype of place Connaught Place.
# Print the entityid and entitytype

# %%
import requests
import json
from requests.auth import HTTPBasicAuth

para={"query":"Connaught Place"}
header={"user-key":"db5cc0c3fa8e6679c4f19aeb201c1c0c"}
a=requests.get('https://developers.zomato.com/api/v2.1/locations',params=para,headers=header)
pdata=json.loads(a.text)
# print(a.url)
print(pdata['location_suggestions'][0]['entity_type'],end=' ')
print(pdata['location_suggestions'][0]['entity_id'],end=' ')
# Out:
# https://developers.zomato.com/api/v2.1/locations?query=Connaught+Place
# subzone 104

# %% [markdown]
# Fetch the top 10 best-rated restaurant serving ‘Mexican’ cuisine present in Connaught Place.
# Print the restaurant name, user rating and restaurant id.

# %%
import requests
import json
header={"user-key":"db5cc0c3fa8e6679c4f19aeb201c1c0c"}
para2={"entity_id":104,"entity_type":'subzone',"sort":"rating","order":"desc","cuisines":73}
b=requests.get("https://developers.zomato.com/api/v2.1/search",params=para2,headers=header)
pdata=json.loads(b.text)

counter=0
for i in pdata['restaurants']:
    counter=counter+1
    
    
    print(i['restaurant']['name'],end=' ')
    print(i['restaurant']['user_rating']['aggregate_rating'],end=' ')
    print(i['restaurant']['id'])
    if(counter==10):
        break
# Out:
# 38 Barracks 4.8 18241537
# Detroit 4.7 18625812
# Xero Degrees 4.7 18729557
# Chili's Grill & Bar 4.6 18537536
# HotMess 4.6 18279449
# Ministry Of Beer 4.5 18418277
# The Darzi Bar & Kitchen 4.5 18423151
# Station Bar 4.5 18851371
# Odeon Social 4.4 18246991
# Punjabi By Nature 4.4 306497

# %% [markdown]
# Fetch the category id of category type ‘Cafes’ using Zomato API.

# %%
import requests
import json
import pprint
header={"user-key":"db5cc0c3fa8e6679c4f19aeb201c1c0c"}
para={"entity_id":104,"entity_type":'subzone',"sort":"rating","order":"desc","cuisines":73}
b=requests.get("https://developers.zomato.com/api/v2.1/categories",headers=header)
pdata=json.loads(b.text)

# pprint.pprint(pdata['categories'])
for i in pdata['categories']:
    if(i['categories']['name']=="Cafes"):
        print(i['categories']['id'])
# Out:
# 6

# %%
import requests
import json
header={"user-key":"db5cc0c3fa8e6679c4f19aeb201c1c0c"}
para2={"entity_id":104,"entity_type":'subzone',"sort":"rating","order":"desc","cuisines":73,"category":6}
b=requests.get("https://developers.zomato.com/api/v2.1/search",params=para2,headers=header)
pdata=json.loads(b.text)

counter=0
for i in pdata['restaurants']:
    counter=counter+1
    
    
    print(i['restaurant']['name'],end=' ')
    print(i['restaurant']['user_rating']['aggregate_rating'],end=' ')
    print(i['restaurant']['id'])
# Out:
# 38 Barracks 4.8 18241537
# Xero Degrees 4.7 18729557
# Rooh Burger Cafe 4.1 18600858
# Chaayos 4.1 18237315
# The Art House Bar n Cafe 3.9 18863766
# The Chai Story 3.8 18445782
# Cafe Coffee Day - The Square 3.7 303034

# %% [markdown]
# Fetch the latest review of the best-rated restaurant for ‘Mexican’ cuisine with Category type ‘Cafes’ present in Connaught Place using Zomato API.
# Print the name of user ,user rating and review text.
# Note :
# Due to limitation of basic API plan it, can only fetch 5 latest review

# %%
import requests
import json
header={"user-key":"db5cc0c3fa8e6679c4f19aeb201c1c0c"}
para2={"res_id":18241537}
b=requests.get("https://developers.zomato.com/api/v2.1/reviews",params=para2,headers=header)
pdata=json.loads(b.text)
# pprint.pprint(pdata['user_reviews'])
for i in pdata['user_reviews']:
    print(i['review']['user']['name'],end=' ')
    print(i['review']['rating'],end=' ')
    print(i['review']['review_text'])
# Out:
# Mansi Sharma 5 An armed forces based theme gives it an edge. Loved the concept . Wide range of food items to satisfy your taste buds. One of the few dine o...
# Shrestha Saha 5 Amazing classy ambience great food and great service ..: Had salt and pepper chicken and it was super tasty ... They also have great deals o...
# Foodie_Biker 5 Located in the heart of the capital city, Connaught Place. It is spread across two floors wherein the ground floor seems best for party hopp...
# Shreya Vohra 5 Very nice place, amazing food and ambience. Live music's great! Romantic, No. Kudos to the Azad and team for exceptional service! :-) They g...
# Himanshu Chichra 5 Awesome food and great service. Jaspal Singh Rawat aka Jaspal was a great help in deciding and serving food. Thumbs up to him for modifying ...

# %%
import pprint
import requests
import json
header={"user-key":"db5cc0c3fa8e6679c4f19aeb201c1c0c"}
para2={"res_id":18241524}
b=requests.get("https://developers.zomato.com/api/v2.1/search",params=para2,headers=header)
pdata=json.loads(b.text)
pprint.pprint(pdata)
# for i in pdata['user_reviews']:
#     print(i['review'],end=' ')
# #     print(i['review']['rating'],end=' ')
# #     print(i['review']['review_text'])
# Out:
# {'restaurants': [{'restaurant': {'R': {'res_id': 18834715},
#                                  'apikey': 'db5cc0c3fa8e6679c4f19aeb201c1c0c',
#                                  'average_cost_for_two': 0,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'North Indian',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/18834715',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/raebareli/batohi-restaurant-raebareli-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 0,
#                                  'has_table_booking': 0,
#                                  'id': '18834715',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'Khozanpur, Unchahar, '
#                                                          'Raebareli Locality, '
#                                                          'Raebareli',
#                                               'city': 'Raebareli',
#                                               'city_id': 11418,
#                                               'country_id': 1,
#                                               'latitude': '26.2212520000',
#                                               'locality': 'Raebareli Locality',
#                                               'locality_verbose': 'Raebareli '
#                                                                   'Locality, '
#                                                                   'Raebareli',
#                                               'longitude': '81.2408030000',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/raebareli/batohi-restaurant-raebareli-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Batohi Restaurant',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/raebareli/batohi-restaurant-raebareli-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/raebareli/batohi-restaurant-raebareli-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': 0,
#                                                  'rating_color': 'CBCBC8',
#                                                  'rating_text': 'Not rated',
#                                                  'votes': 0}}},
#                  {'restaurant': {'R': {'res_id': 19057956},
#                                  'apikey': 'db5cc0c3fa8e6679c4f19aeb201c1c0c',
#                                  'average_cost_for_two': 300,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Pizza, Burger',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19057956',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/raniganj/la-pizzario-raniganj-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 0,
#                                  'has_table_booking': 0,
#                                  'id': '19057956',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': '99, NSB Road, '
#                                                          'Raniganj, Raniganj '
#                                                          'Locality, Raniganj',
#                                               'city': 'Raniganj',
#                                               'city_id': 11602,
#                                               'country_id': 1,
#                                               'latitude': '23.6194476920',
#                                               'locality': 'Raniganj Locality',
#                                               'locality_verbose': 'Raniganj '
#                                                                   'Locality, '
#                                                                   'Raniganj',
#                                               'longitude': '87.1138019487',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/raniganj/la-pizzario-raniganj-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'La Pizzario',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/raniganj/la-pizzario-raniganj-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/raniganj/la-pizzario-raniganj-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': 0,
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': 'CBCBC8',
#                                                  'rating_text': 'Not rated',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': 0}}},
#                  {'restaurant': {'R': {'res_id': 3100743},
#                                  'apikey': 'db5cc0c3fa8e6679c4f19aeb201c1c0c',
#                                  'average_cost_for_two': 200,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Desserts, Ice Cream',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/3100743',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/moodbidri/frozen-bowl-moodbidri-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '3100743',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 1,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'G-22, Vishwas '
#                                                          'Pineapple City, Opp. '
#                                                          'G V Pai Hospital, '
#                                                          'Moodbidri Locality, '
#                                                          'Moodbidri',
#                                               'city': 'Moodbidri',
#                                               'city_id': 11567,
#                                               'country_id': 1,
#                                               'latitude': '13.0695904000',
#                                               'locality': 'Moodbidri Locality',
#                                               'locality_verbose': 'Moodbidri '
#                                                                   'Locality, '
#                                                                   'Moodbidri',
#                                               'longitude': '74.9975152000',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/moodbidri/frozen-bowl-moodbidri-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Frozen Bowl',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'order_deeplink': '',
#                                  'order_url': 'https://www.zomato.com/moodbidri/frozen-bowl-moodbidri-locality/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'photos_url': 'https://www.zomato.com/moodbidri/frozen-bowl-moodbidri-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/moodbidri/frozen-bowl-moodbidri-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': 0,
#                                                  'rating_color': 'CBCBC8',
#                                                  'rating_text': 'Not rated',
#                                                  'votes': 0}}},
#                  {'restaurant': {'R': {'res_id': 19012266},
#                                  'apikey': 'db5cc0c3fa8e6679c4f19aeb201c1c0c',
#                                  'average_cost_for_two': 150,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Andhra, Biryani, Chinese, Fast '
#                                              'Food, Kebab, North Indian, '
#                                              'Seafood, South Indian',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19012266',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/srikakulam/relax-hotel-srikakulam-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '19012266',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'GT Road, Near '
#                                                          'Ram-Laxmana '
#                                                          'jn.,Srikakulam, '
#                                                          'Andhra Pradesh',
#                                               'city': 'Srikakulam',
#                                               'city_id': 11452,
#                                               'country_id': 1,
#                                               'latitude': '18.2986460884',
#                                               'locality': 'Srikakulam Locality',
#                                               'locality_verbose': 'Srikakulam '
#                                                                   'Locality, '
#                                                                   'Srikakulam',
#                                               'longitude': '83.9046877250',
#                                               'zipcode': '532001'},
#                                  'menu_url': 'https://www.zomato.com/srikakulam/relax-hotel-srikakulam-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Relax Hotel',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/srikakulam/relax-hotel-srikakulam-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/srikakulam/relax-hotel-srikakulam-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': '4.2',
#                                                  'rating_color': '5BA829',
#                                                  'rating_text': 'Very Good',
#                                                  'votes': '36'}}},
#                  {'restaurant': {'R': {'res_id': 19054293},
#                                  'apikey': 'db5cc0c3fa8e6679c4f19aeb201c1c0c',
#                                  'average_cost_for_two': 200,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Juices, Desserts',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19054293',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/chikmagalur/lassi-shop-chikmagalur-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '19054293',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'IG Road, Chikmagalur '
#                                                          'Locality, '
#                                                          'Chikmagalur',
#                                               'city': 'Chikmagalur',
#                                               'city_id': 11546,
#                                               'country_id': 1,
#                                               'latitude': '13.3300043750',
#                                               'locality': 'Chikmagalur '
#                                                           'Locality',
#                                               'locality_verbose': 'Chikmagalur '
#                                                                   'Locality, '
#                                                                   'Chikmagalur',
#                                               'longitude': '75.7727738097',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/chikmagalur/lassi-shop-chikmagalur-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Lassi Shop ',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/chikmagalur/lassi-shop-chikmagalur-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/chikmagalur/lassi-shop-chikmagalur-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': '3.4',
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': 'CDD614',
#                                                  'rating_text': 'Average',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': '60'}}},
#                  {'restaurant': {'R': {'res_id': 19028765},
#                                  'apikey': 'db5cc0c3fa8e6679c4f19aeb201c1c0c',
#                                  'average_cost_for_two': 200,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Bakery, Beverages',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19028765',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/kundapura-koteshwar/cubs-cool-corner-kundapura-koteshwar-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '19028765',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 1,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'Vaishali Complex, '
#                                                          'Shastri Circle, '
#                                                          'Kundapura-Koteshwar '
#                                                          'Locality, '
#                                                          'Kundapura-Koteshwar',
#                                               'city': 'Kundapura-Koteshwar',
#                                               'city_id': 11569,
#                                               'country_id': 1,
#                                               'latitude': '13.6243070000',
#                                               'locality': 'Kundapura-Koteshwar '
#                                                           'Locality',
#                                               'locality_verbose': 'Kundapura-Koteshwar '
#                                                                   'Locality, '
#                                                                   'Kundapura-Koteshwar',
#                                               'longitude': '74.6917410000',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/kundapura-koteshwar/cubs-cool-corner-kundapura-koteshwar-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Cubs Cool Corner',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'order_deeplink': '',
#                                  'order_url': 'https://www.zomato.com/kundapura-koteshwar/cubs-cool-corner-kundapura-koteshwar-locality/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'photos_url': 'https://www.zomato.com/kundapura-koteshwar/cubs-cool-corner-kundapura-koteshwar-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/kundapura-koteshwar/cubs-cool-corner-kundapura-koteshwar-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': 0,
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': 'CBCBC8',
#                                                  'rating_text': 'Not rated',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': 0}}},
#                  {'restaurant': {'R': {'res_id': 18707294},
#                                  'apikey': 'db5cc0c3fa8e6679c4f19aeb201c1c0c',
#                                  'average_cost_for_two': 250,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'North Indian',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/18707294',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/kota/amar-punjabi-foods-talwandi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': 'https://b.zmtcdn.com/data/pictures/4/18707294/5e9eb3b68de1deaf7590a17b414f017b.jpg',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '18707294',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 1,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': '4-A-18, Rangbari '
#                                                          'Road, Keshavpura '
#                                                          'Circle, Sector 4, '
#                                                          'Talwandi, Kota',
#                                               'city': 'Kota',
#                                               'city_id': 11302,
#                                               'country_id': 1,
#                                               'latitude': '25.1480382632',
#                                               'locality': 'Talwandi',
#                                               'locality_verbose': 'Talwandi, '
#                                                                   'Kota',
#                                               'longitude': '75.8369738236',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/kota/amar-punjabi-foods-talwandi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Amar Punjabi Foods',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'order_deeplink': '',
#                                  'order_url': 'https://www.zomato.com/kota/amar-punjabi-foods-talwandi/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'photos_url': 'https://www.zomato.com/kota/amar-punjabi-foods-talwandi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': 'https://b.zmtcdn.com/data/pictures/4/18707294/5e9eb3b68de1deaf7590a17b414f017b.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#                                  'url': 'https://www.zomato.com/kota/amar-punjabi-foods-talwandi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': '4.8',
#                                                  'rating_color': '3F7E00',
#                                                  'rating_text': 'Excellent',
#                                                  'votes': '2296'}}},
#                  {'restaurant': {'R': {'res_id': 19057861},
#                                  'apikey': 'db5cc0c3fa8e6679c4f19aeb201c1c0c',
#                                  'average_cost_for_two': 300,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'South Indian, North Indian, '
#                                              'Chinese',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19057861',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/raniganj/abhinandan-raniganj-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 0,
#                                  'has_table_booking': 0,
#                                  'id': '19057861',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'B/34, NSB Road '
#                                                          'Raniganj, Raniganj '
#                                                          'Locality, Raniganj',
#                                               'city': 'Raniganj',
#                                               'city_id': 11602,
#                                               'country_id': 1,
#                                               'latitude': '23.6086000933',
#                                               'locality': 'Raniganj Locality',
#                                               'locality_verbose': 'Raniganj '
#                                                                   'Locality, '
#                                                                   'Raniganj',
#                                               'longitude': '87.1147658676',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/raniganj/abhinandan-raniganj-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Abhinandan',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/raniganj/abhinandan-raniganj-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/raniganj/abhinandan-raniganj-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': 0,
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': 'CBCBC8',
#                                                  'rating_text': 'Not rated',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': 0}}},
#                  {'restaurant': {'R': {'res_id': 18837264},
#                                  'apikey': 'db5cc0c3fa8e6679c4f19aeb201c1c0c',
#                                  'average_cost_for_two': 200,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Desserts',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/18837264',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/kanchipuram/meet-me-ice-cream-parlour-kanchipuram-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '18837264',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 1,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'No.36, Hospital '
#                                                          'Road, Kanchipuram - '
#                                                          '631501, Near Bus '
#                                                          'Stand Opp Arya '
#                                                          'Scans, Kanchipuram '
#                                                          'Locality, '
#                                                          'Kanchipuram',
#                                               'city': 'Kanchipuram',
#                                               'city_id': 11406,
#                                               'country_id': 1,
#                                               'latitude': '12.8372311847',
#                                               'locality': 'Kanchipuram '
#                                                           'Locality',
#                                               'locality_verbose': 'Kanchipuram '
#                                                                   'Locality, '
#                                                                   'Kanchipuram',
#                                               'longitude': '79.7044198215',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/kanchipuram/meet-me-ice-cream-parlour-kanchipuram-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Meet Me Ice Cream Parlour',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'order_deeplink': '',
#                                  'order_url': 'https://www.zomato.com/kanchipuram/meet-me-ice-cream-parlour-kanchipuram-locality/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'photos_url': 'https://www.zomato.com/kanchipuram/meet-me-ice-cream-parlour-kanchipuram-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/kanchipuram/meet-me-ice-cream-parlour-kanchipuram-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': '3.5',
#                                                  'rating_color': '9ACD32',
#                                                  'rating_text': 'Good',
#                                                  'votes': '4'}}},
#                  {'restaurant': {'R': {'res_id': 19054887},
#                                  'apikey': 'db5cc0c3fa8e6679c4f19aeb201c1c0c',
#                                  'average_cost_for_two': 200,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'North Indian, Chinese',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19054887',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/silchar/china-town-silchar-locality-silchar-city/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 0,
#                                  'has_table_booking': 0,
#                                  'id': '19054887',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 0,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'UKD Sarani, '
#                                                          'Premtola, Silchar '
#                                                          'Locality, Silchar '
#                                                          'City',
#                                               'city': 'Silchar City',
#                                               'city_id': 11516,
#                                               'country_id': 1,
#                                               'latitude': '24.8226106882',
#                                               'locality': 'Silchar Locality',
#                                               'locality_verbose': 'Silchar '
#                                                                   'Locality, '
#                                                                   'Silchar '
#                                                                   'City',
#                                               'longitude': '92.7986085043',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/silchar/china-town-silchar-locality-silchar-city/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'China Town',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'photos_url': 'https://www.zomato.com/silchar/china-town-silchar-locality-silchar-city/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/silchar/china-town-silchar-locality-silchar-city?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': 0,
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': 'CBCBC8',
#                                                  'rating_text': 'Not rated',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': 0}}},
#                  {'restaurant': {'R': {'res_id': 19054638},
#                                  'apikey': 'db5cc0c3fa8e6679c4f19aeb201c1c0c',
#                                  'average_cost_for_two': 300,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Seafood, Roast Chicken, Charcoal '
#                                              'Chicken',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19054638',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/porbandar/m-s-national-restaurant-porbandar-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '19054638',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 1,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'MG Road, Op Dream '
#                                                          'Land, Porbandar, '
#                                                          'Porbandar Locality, '
#                                                          'Porbandar',
#                                               'city': 'Porbandar',
#                                               'city_id': 11560,
#                                               'country_id': 1,
#                                               'latitude': '21.6407886178',
#                                               'locality': 'Porbandar Locality',
#                                               'locality_verbose': 'Porbandar '
#                                                                   'Locality, '
#                                                                   'Porbandar',
#                                               'longitude': '69.6041631326',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/porbandar/m-s-national-restaurant-porbandar-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'M/S National Restaurant',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'order_deeplink': '',
#                                  'order_url': 'https://www.zomato.com/porbandar/m-s-national-restaurant-porbandar-locality/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'photos_url': 'https://www.zomato.com/porbandar/m-s-national-restaurant-porbandar-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/porbandar/m-s-national-restaurant-porbandar-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': '3.8',
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': '9ACD32',
#                                                  'rating_text': 'Good',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
# ...
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': 0}}},
#                  {'restaurant': {'R': {'res_id': 19060659},
#                                  'apikey': 'db5cc0c3fa8e6679c4f19aeb201c1c0c',
#                                  'average_cost_for_two': 200,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'South Indian, Sandwich, Pizza, '
#                                              'Juices, Ice Cream, Coffee, '
#                                              'Chinese, Burger',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19060659',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/sri-ganganagar/the-spicy-saga-sri-ganganagar-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '19060659',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 1,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': '236 Mukherjee Nagar '
#                                                          'Payal Cinema Road '
#                                                          'Sri Ganganagar, Sri '
#                                                          'Ganganagar Locality, '
#                                                          'Sri Ganganagar',
#                                               'city': 'Sri Ganganagar',
#                                               'city_id': 11462,
#                                               'country_id': 1,
#                                               'latitude': '29.9214040000',
#                                               'locality': 'Sri Ganganagar '
#                                                           'Locality',
#                                               'locality_verbose': 'Sri '
#                                                                   'Ganganagar '
#                                                                   'Locality, '
#                                                                   'Sri '
#                                                                   'Ganganagar',
#                                               'longitude': '73.8658920000',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/sri-ganganagar/the-spicy-saga-sri-ganganagar-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'The Spicy Saga ',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'order_deeplink': '',
#                                  'order_url': 'https://www.zomato.com/sri-ganganagar/the-spicy-saga-sri-ganganagar-locality/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'photos_url': 'https://www.zomato.com/sri-ganganagar/the-spicy-saga-sri-ganganagar-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/sri-ganganagar/the-spicy-saga-sri-ganganagar-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': '3.6',
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': '9ACD32',
#                                                  'rating_text': 'Good',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': '57'}}},
#                  {'restaurant': {'R': {'res_id': 19026435},
#                                  'apikey': 'db5cc0c3fa8e6679c4f19aeb201c1c0c',
#                                  'average_cost_for_two': 400,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'North Indian, Desserts, Fast '
#                                              'Food, Chinese, Beverages',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19026435',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/sikar/the-roti-sikar-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '19026435',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 1,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'Shop 02, Bioscope '
#                                                          'Cinemall, Rani Sati '
#                                                          'Road, Sikar, Sikar '
#                                                          'Locality, Sikar',
#                                               'city': 'Sikar',
#                                               'city_id': 11557,
#                                               'country_id': 1,
#                                               'latitude': '27.6009610000',
#                                               'locality': 'Sikar Locality',
#                                               'locality_verbose': 'Sikar '
#                                                                   'Locality, '
#                                                                   'Sikar',
#                                               'longitude': '75.1458190000',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/sikar/the-roti-sikar-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'The Roti',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'order_deeplink': '',
#                                  'order_url': 'https://www.zomato.com/sikar/the-roti-sikar-locality/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'photos_url': 'https://www.zomato.com/sikar/the-roti-sikar-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 2,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/sikar/the-roti-sikar-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': '3.5',
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': '9ACD32',
#                                                  'rating_text': 'Good',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': '125'}}},
#                  {'restaurant': {'R': {'res_id': 19053732},
#                                  'apikey': 'db5cc0c3fa8e6679c4f19aeb201c1c0c',
#                                  'average_cost_for_two': 100,
#                                  'book_again_url': '',
#                                  'book_form_web_view_url': '',
#                                  'cuisines': 'Beverages',
#                                  'currency': 'Rs.',
#                                  'deeplink': 'zomato://restaurant/19053732',
#                                  'establishment_types': [],
#                                  'events_url': 'https://www.zomato.com/kolar/lassi-shop-kolar-locality-kolar-city/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'featured_image': '',
#                                  'has_online_delivery': 1,
#                                  'has_table_booking': 0,
#                                  'id': '19053732',
#                                  'include_bogo_offers': True,
#                                  'is_book_form_web_view': 0,
#                                  'is_delivering_now': 1,
#                                  'is_table_reservation_supported': 0,
#                                  'is_zomato_book_res': 0,
#                                  'location': {'address': 'Next to Prabhath '
#                                                          'Talkies, Kolar '
#                                                          'Locality, Kolar City',
#                                               'city': 'Kolar City',
#                                               'city_id': 11499,
#                                               'country_id': 1,
#                                               'latitude': '13.1367380000',
#                                               'locality': 'Kolar Locality',
#                                               'locality_verbose': 'Kolar '
#                                                                   'Locality, '
#                                                                   'Kolar City',
#                                               'longitude': '78.1344790000',
#                                               'zipcode': ''},
#                                  'menu_url': 'https://www.zomato.com/kolar/lassi-shop-kolar-locality-kolar-city/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#                                  'mezzo_provider': 'OTHER',
#                                  'name': 'Lassi Shop ',
#                                  'offers': [],
#                                  'opentable_support': 0,
#                                  'order_deeplink': '',
#                                  'order_url': 'https://www.zomato.com/kolar/lassi-shop-kolar-locality-kolar-city/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'photos_url': 'https://www.zomato.com/kolar/lassi-shop-kolar-locality-kolar-city/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#                                  'price_range': 1,
#                                  'switch_to_order_menu': 0,
#                                  'thumb': '',
#                                  'url': 'https://www.zomato.com/kolar/lassi-shop-kolar-locality-kolar-city?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#                                  'user_rating': {'aggregate_rating': 0,
#                                                  'custom_rating_text': 'NEW',
#                                                  'custom_rating_text_background': '#89959B',
#                                                  'rating_color': 'CBCBC8',
#                                                  'rating_text': 'Not rated',
#                                                  'rating_tool_tip': 'This '
#                                                                     'restaurant '
#                                                                     'is newly '
#                                                                     'opened. '
#                                                                     'The '
#                                                                     'rating '
#                                                                     'will '
#                                                                     'appear '
#                                                                     'once the '
#                                                                     'restaurant '
#                                                                     'completes '
#                                                                     '60 days '
#                                                                     'in '
#                                                                     'operation.',
#                                                  'votes': 0}}}],
#  'results_found': 1418905,
#  'results_shown': 20,
#  'results_start': 0}

# %%
import requests
import json
header={"user-key":"db5cc0c3fa8e6679c4f19aeb201c1c0c"}
para2={"res_id":18241524}
b=requests.get("https://developers.zomato.com/api/v2.1/reviews",params=para2,headers=header)
pdata=json.loads(b.text)
# pprint.pprint(pdata['user_reviews'])
for i in pdata['user_reviews']:
    print(i['review']['user']['name'],end=' ')
    print(i['review']['rating'],end=' ')
    print(i['review']['review_text'])
# Out:
# Abhay Alok 5 This is best lounge in hudson lane. You can chill here with friends .it is best for birthday parties and many other parties like farewell pa...
# Bskhatihun ❤️ 4 This place has awesome ambience and vibrant dj that will surely make you dance. I tried garlic bread and honey chilli potato. I don't like i...
# RITIKA 🍸 4 736 A.D. cafe located at Hudson Lane is a wonderful place one must visit. I've visited this cafe twice . The food was so appetizing and deli...
# Tarang Gupta 5 736 A.D., beautiful cafe located at Hudson Lane is a wonderful place one should must visit. Twice I've visited this cafe . The food was so a...
# Nandini 5 So my friend gave his birthday party...First of all Thier dark and rusty ambience was giving me the feels of ancient time...Now come to the ...

# %%
lat,lon="28.4152","77.08261"

# %%
import requests
import json
from requests.auth import HTTPBasicAuth

para={"city_id":1}
header={"user-key":"db5cc0c3fa8e6679c4f19aeb201c1c0c"}
a=requests.get('https://developers.zomato.com/api/v2.1/cuisines',params=para,headers=header)
pdata=json.loads(a.text)

for i in pdata['cuisines']:
    if (i['cuisine']['cuisine_name']=='BBQ'):
        print(i['cuisine']['cuisine_id'])
# Out:
# https://developers.zomato.com/api/v2.1/cuisines?city_id=1
# 193

# %%
import pprint
import requests
import json
header={"user-key":"db5cc0c3fa8e6679c4f19aeb201c1c0c"}
para={"lat":28.697758,"lon":77.140643,"cuisines":193,"sort":"real_distance","order":"asc"}
b=requests.get("https://developers.zomato.com/api/v2.1/search",params=para,headers=header)
pdata=json.loads(b.text)
counter=0
# pprint.pprint(pdata['restaurants'][0]['restaurant'])
for i in pdata['restaurants']:
    counter=counter+1
    print(i['restaurant']['name'],end=' ')
    print(i['restaurant']['user_rating']['aggregate_rating'],end=' ')
    print(i['restaurant']['R']['res_id'],end=' ')
    print(i['restaurant']['location']['locality'])
    
    if counter==10:
        break
# Out:
# Themis Barbecue House 4.5 18204820 Netaji Subhash Place
# Barbeque Nation 4.2 9561 Netaji Subhash Place
# New Bombay Bar-Be-Que 3.6 5303 Prashant Vihar
# Changezi Bar-be-que & Mughlai 0 19050115 Rohini
# Wow! Chicken 0 18998624 Rohini
# Wong's Kitchen 3.9 18561585 Rohini
# 7teen BBQ Bistro Bnq 3.9 18595610 Moti Nagar
# Pishori Chicken 0 19061375 Kirti Nagar
# Roast Barbecue & Grill 4.4 18720398 Rajouri Garden
# Wow! Chicken 0 18996355 Paschim Vihar

# %%
import pprint
import requests
import json
header={"user-key":"db5cc0c3fa8e6679c4f19aeb201c1c0c"}
para={"lat":28.697758,"lon":77.140643,"cuisines":193,"sort":"real_distance","order":"asc"}
a=requests.get("https://developers.zomato.com/api/v2.1/search",params=para,headers=header)
pdata=json.loads(a.text)
counter=0
res_id=pdata['restaurants'][0]['restaurant']['R']['res_id']


para2={"res_id":res_id}
b=requests.get("https://developers.zomato.com/api/v2.1/reviews",params=para2,headers=header)
pdata=json.loads(b.text)
# pprint.pprint(pdata['user_reviews'])
for i in pdata['user_reviews']:
    print(i['review']['user']['name'],end=' ')
    print(i['review']['rating'],end=' ')
    print(i['review']['review_text'])
# Out:
# Grishma Ashwin 4 The spot was awesome pleasant atmosphere. Starter was generally amazing. I had boundless non veg buffet. So I adore each starter and the pri...
# Deepanshu Meemroth 4 This is the best place for foodies, and the best part about this place is their deserts i just love them way too much. Moreover, the package...
# SR 1 Not recommended to anyone! Found a living cockroach in their salad! Food is of poor quality. Pathetic service, extremely slow. The worst is ...
# Priyanka Sachdeva 5 I think i was the 8 or 9th time we have been their for lunch l.  Really wanna give special thanks to chef nitish he is the best chef who alw...
# Anirudh Gautam 2 Service not at all up to the mark..moreover food was of average quality...they billed us wrong...servers were not at interested in serving a...

# %%
import pprint
import requests
import json
header={"user-key":"db5cc0c3fa8e6679c4f19aeb201c1c0c"}
para={"lat":28.697758,"lon":77.140643,"radius":4000.0,"sort":"rating","order":"desc"}
b=requests.get("https://developers.zomato.com/api/v2.1/search",params=para,headers=header)
pdata=json.loads(b.text)
counter=0
# pprint.pprint(pdata['restaurants'][0]['restaurant'])
for i in pdata['restaurants']:
    counter=counter+1
    print(i['restaurant']['name'],end=' ')
    print(i['restaurant']['user_rating']['aggregate_rating'],end=' ')
    print(i['restaurant']['R']['res_id'],end=' ')
    print(i['restaurant']['location']['locality'])
    
    if counter==10:
        break
# Out:
# Cafe Wink 4.9 7224 Anand Vihar
# Sanadige 4.9 18265393 Chanakyapuri
# Moonshine Cafe and Bar 4.9 18900875 Hauz Khas Village
# Ah So Yum 4.9 18945610 DLF Galleria, DLF Phase 4
# Street 9 Bar & Lounge 4.9 18812732 M Block Market, Greater Kailash 2 (GK2)
# Hudson Oven 4.9 18780732 Delhi University-GTB Nagar
# Chili's Grill & Bar 4.8 18607069 Pacific Mall, Tagore Garden
# Chili's Grill & Bar 4.8 4751 Ambience Mall, Vasant Kunj
# The Yellow Chilli 4.8 1345 Pacific Mall, Sahibabad
# 38 Barracks 4.8 18241537 Connaught Place
