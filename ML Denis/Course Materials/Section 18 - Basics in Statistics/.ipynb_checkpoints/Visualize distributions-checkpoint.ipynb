# %%
import numpy as np

levels = np.random.normal(300, 10, 10000)
print(levels)
# Out:
# [ 307.00092219  301.66500819  303.46706665 ...,  294.48732605  297.12826547
#   300.58397059]

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.hist(levels, bins = 100)
plt.xlim(100, 500)
plt.show()

# %%
import numpy as np

levels2 = np.random.normal(300, 50, 10000)

# %matplotlib inline

import matplotlib.pyplot as plt

plt.hist(levels2, bins = 100)
plt.xlim(100, 500)
plt.show()
